# %%
from geopy.geocoders import Nominatim
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# Manual test of geopy

# %%
locator = Nominatim(user_agent='my_email@myserver.com')

# %%
tjek = print(locator.geocode("Carolinehaven 20, 2665, 2300", language="dk"))
# Out:
# None

# %%
location = locator.geocode('Carolinehaven 6, 2665')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/Library/r-miniconda/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Library/r-miniconda/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# ...

# %%
print((location.latitude, location.longitude))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print((location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %% [markdown]
# Read data

# %%
df = pd.read_csv('/Users/christinethier/Desktop/CBS Cand.Merc.(Mat.)/Speciale/XGBoost - R/database/0102_data_modify_new.csv')
df = pd.DataFrame(df)
df['lat'] = 0
df['long'] = 0

# %%
df[19677+254+20:]
# Out:
#                                                  adresse     pris   salgsdato  \
# 19951           Lyngvej 1, st. 4 2665 Vallensbæk Strand   1400000  2018-06-06
# 19952   Vejlegårdsparken 40, st. 4 2665 Vallensbæk St...  1000000  2018-06-02
# 19953       Delta Park 32, 8. th 2665 Vallensbæk Strand   2875000  2018-05-31
# 19954   Gammelgårds Alle 17, 2. 27 2665 Vallensbæk St...  1100000  2018-05-29
# 19955   Vejlegårdsparken 2, 1. 15 2665 Vallensbæk Str...  1073000  2018-05-28
# ...                                                  ...      ...         ...
# 47222                     Vestbirk Alle 18 2770 Kastrup   1522378  2018-01-14
# 47223                   Tårnbypark Alle 10 2770 Kastrup   3700000  2018-01-09
# 47224                         Bryrupvej 38 2770 Kastrup   3595000  2018-01-06
# 47225                      Hadsten Alle 16 2770 Kastrup   3448000  2018-01-04
# 47226                          Uldumvej 18 2770 Kastrup   3100000  2018-01-03
#
# ...

# %% [markdown]
# Get lonetude and latitude from GeoPy

# %%
for i in tqdm(range(19953+21370+1,len(df))):
    string = df['adresse_3'][i]
    location = locator.geocode(string)
    if location != None:
        df.iloc[i,20] = location.latitude
        df.iloc[i,21] = location.longitude
# Out:
# 100%|██████████| 5903/5903 [49:12<00:00,  2.00it/s]

# %% [markdown]
# Save as CSV-file (Kun udkommenter og gem hvis du er helt sikker på at vi skal overskrive den forrige fil, ellers tager det 6 timer at genere data igen )

# %%
#df.to_csv('/Users/christinethier/Desktop/CBS Cand.Merc.(Mat.)/Speciale/XGBoost - R/database/0103_python_modify_new.csv', encoding='utf-8')
